# %% [markdown]
# <a href="https://colab.research.google.com/github/aladetolulope/alade/blob/master/AladTolulope_Hamoye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure (figsize=(10,7))

# %%
 import requests # This library is used to make requests to internet
 
# We are storing url of dataset
#url'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'
# We are creating a requests variable with the above url
r = requests.get(url, allow_redirects=True)
 
open('fuel_ferc1.csv','wb').write(r.content)
 
# Now, we have our files downloaded 
# Printing the content of file
fuel = open('fuel_ferc1.csv','r')
for lines in fuel:
    print(lines)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# f1_fuel_2016_12_144_2_11,144,2016,miami wabash,oil,bbl,348.0,5.7540000000000004,114.498,0.0,19.899
#
# f1_fuel_2016_12_144_2_14,144,2016,vermillion,gas,mcf,1195139.0,1.0,2.893,2.893,2.814
#
# f1_fuel_2016_12_144_3_1,144,2016,edwardsport igcc,coal,ton,1148082.0,22.39,41.22,40.719,1.841
#
# f1_fuel_2016_12_144_3_3,144,2016,edwardsport igcc,gas,mcf,8688246.0,1.0,2.948,2.948,2.868
#
# f1_fuel_2016_12_177_0_1,177,2016,labadie,coal,ton,8512712.0,17.572,38.812,38.977,2.209
#
# f1_fuel_2016_12_177_0_2,177,2016,labadie,oil,bbl,26562.0,5.756562,65.686,63.905,11.411
#
# f1_fuel_2016_12_177_0_4,177,2016,sioux,coal,ton,2646136.0,18.388,39.1,38.277,2.126
#
# f1_fuel_2016_12_177_0_5,177,2016,sioux,oil,bbl,6060.0,5.7540000000000004,64.739,65.265,11.251
#
# f1_fuel_2016_12_177_0_7,177,2016,rush island,coal,ton,3954447.0,17.066000000000003,38.233,38.521,2.24
#
# ...

# %%
 fuel_data = pd.read_csv('fuel_ferc1.csv')
fuel_data.describe(include='all')
# Out:
#                        record_id  ...  fuel_cost_per_mmbtu
# count                      29523  ...         29523.000000
# unique                     29523  ...                  NaN
# top     f1_fuel_1995_12_133_1_11  ...                  NaN
# freq                           1  ...                  NaN
# mean                         NaN  ...            19.304354
# std                          NaN  ...          2091.540939
# min                          NaN  ...           -41.501000
# 25%                          NaN  ...             1.940000
# 50%                          NaN  ...             4.127000
# 75%                          NaN  ...             7.745000
# max                          NaN  ...        359278.000000
#
# [11 rows x 11 columns]
